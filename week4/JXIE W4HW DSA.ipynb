# %% [markdown]
# # Exercise 1.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Try to reproduce the figure shown in images/exercise_1-1.png

# Our data...
x = np.linspace(0, 10, 100)
y1, y2, y3 = np.cos(x), np.cos(x + 1), np.cos(x + 2)
names = ['Signal 1', 'Signal 2', 'Signal 3']

# Can you figure out what to do next to plot x vs y1, y2, and y3 on one figure?

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 10))

ys = [y1, y2, y3]

for i in range(len(axes)):
    axes[i].plot(x, ys[i], color='black', linewidth=1)
    axes[i].set(title=names[i])
    axes[i].set_xlim(0,10)
    axes[i].set_ylim(-1,1)
    axes[i].set(xticks=[], yticks=[])
    
plt.show()

# %% [markdown]
# # Exercise 2.1

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1)

# Generate data...
y_raw = np.random.randn(1000).cumsum() + 15
x_raw = np.linspace(0, 24, y_raw.size)

# Get averages of every 100 samples...
x_pos = x_raw.reshape(-1, 100).min(axis=1)
y_avg = y_raw.reshape(-1, 100).mean(axis=1)
y_err = y_raw.reshape(-1, 100).ptp(axis=1)

bar_width = x_pos[1] - x_pos[0]

# Make a made up future prediction with a fake confidence
x_pred = np.linspace(0, 30)
y_max_pred = y_avg[0] + y_err[0] + 2.3 * x_pred
y_min_pred = y_avg[0] - y_err[0] + 1.2 * x_pred

# Just so you don't have to guess at the colors...
barcolor, linecolor, fillcolor = 'wheat', 'salmon', 'lightblue'

# Now you're on your own!

# %%
fig, ax = plt.subplots()
vert_bars = ax.bar(x_pos, y_avg, color=barcolor, align='edge', width=bar_width,
                  edgecolor="gray", yerr=y_err, ecolor="gray", capsize=5)



# Plot the envelope with `fill_between`
ax.fill_between(x_pred, y_max_pred, y_min_pred, color=fillcolor)


# Plot the "centerline" with `plot`
ax.plot(x_raw, y_raw, color=linecolor)

ax.set(title="Future Projection of Attitudes")
ax.set_xlabel("Minutes since class began")
ax.set_ylabel("Snarkiness (snark units)")
ax.set_xlim(0,30)
ax.set_ylim(0,100)

plt.show()

# %% [markdown]
# # Exercise 2.2

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1)

# Generate random data with different ranges...
data1 = np.random.random((10, 10))
data2 = 2 * np.random.random((10, 10))
data3 = 3 * np.random.random((10, 10))

# Set up our figure and axes...
fig, axes = plt.subplots(ncols=3, figsize=plt.figaspect(0.5))
fig.tight_layout() # Make the subplots fill up the figure a bit more...
cax = fig.add_axes([0.25, 0.1, 0.55, 0.03]) # Add an axes for the colorbar

# Now you're on your own!

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1)

# Generate random data with different ranges...
data1 = np.random.random((10, 10))
data2 = 2 * np.random.random((10, 10))
data3 = 3 * np.random.random((10, 10))

# Set up our figure and axes...
fig, axes = plt.subplots(ncols=3, figsize=plt.figaspect(0.5))
fig.tight_layout() # Make the subplots fill up the figure a bit more...
cax = fig.add_axes([0.25, 0.1, 0.55, 0.03]) # Add an axes for the colorbar


data = [data1, data2, data3]
for i in range(len(axes)):
    im = axes[i].imshow(data[i], cmap='viridis') 
    axes[i].set_xticks([0,2,4,6,8])

fig.colorbar(im, cax=cax, orientation='horizontal', ticks=[0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0])
plt.show()


# Ultimately, I can't figure out how to do two things in this task:
# - get the colorbar ticks to display the ones on the ends
# - get the color bar to go across the whole thing instead of appearing to do subplot by subplot
